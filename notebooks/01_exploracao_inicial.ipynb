# %%
import pandas as pd

# Carrega os três arquivos
quotes    = pd.read_csv('../data/raw/friends_quotes.csv')
ep_v2     = pd.read_csv('../data/raw/friends_episodes_v2.csv')
ep_v3     = pd.read_csv('../data/raw/friends_episodes_v3.csv', encoding='latin-1')

# ── Roteiros ──────────────────────────────────────────
print("=" * 50)
print("QUOTES (roteiros)")
print("=" * 50)
print(f"Linhas x Colunas: {quotes.shape}")
print(f"Colunas: {quotes.columns.tolist()}")
print(quotes.head(3))

# ── Episódios v2 ──────────────────────────────────────
print("\n" + "=" * 50)
print("EPISODES V2")
print("=" * 50)
print(f"Linhas x Colunas: {ep_v2.shape}")
print(f"Colunas: {ep_v2.columns.tolist()}")
print(ep_v2.head(3))

# ── Episódios v3 ──────────────────────────────────────
print("\n" + "=" * 50)
print("EPISODES V3")
print("=" * 50)
print(f"Linhas x Colunas: {ep_v3.shape}")
print(f"Colunas: {ep_v3.columns.tolist()}")
print(ep_v3.head(3))
# Out:
# ...
# QUOTES (roteiros)
# ...
# Linhas x Colunas: (60291, 6)
# Colunas: ['author', 'episode_number', 'episode_title', 'quote', 'quote_order', 'season']
#      author  episode_number           episode_title  \
# 0    Monica             1.0  Monica Gets A Roommate
# 1      Joey             1.0  Monica Gets A Roommate
# 2  Chandler             1.0  Monica Gets A Roommate
#
#                                                quote  quote_order  season
# 0  There's nothing to tell! He's just some guy I ...          0.0     1.0
# 1  C'mon, you're going out with the guy! There's ...          1.0     1.0
# 2  All right Joey, be nice. So does he have a hum...          2.0     1.0
#
# ...
# EPISODES V2
# ...
# Linhas x Colunas: (235, 8)
# Colunas: ['Year_of_prod', 'Season', 'Episode_Title', 'Duration', 'Summary', 'Director', 'Stars', 'Votes']
#    Year_of_prod  Season                         Episode_Title  Duration  \
# 0          1994       1  The One with the Sonogram at the End        22
# ...
